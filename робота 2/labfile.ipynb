# %%
from datetime import datetime
name = "Taras"
location = "Berlin"
print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Taras start programming at 2026-01-19 17:11:29.100215. Berlin is the best city!

# %% [markdown]
# # ПамПамПам
